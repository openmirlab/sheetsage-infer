# %%
# Transcribe

AUDIO_URL = 'https://foodgroup.bandcamp.com/track/universe'
USE_JUKEBOX = True
SEGMENT_START_HINT = 69
SEGMENT_END_HINT = 88
BPM_HINT = 76

import logging

from sheetsage.infer import sheetsage

logging.basicConfig(level=logging.INFO)
lead_sheet, segment_beats, segment_beats_times = sheetsage(
    AUDIO_URL,
    use_jukebox=USE_JUKEBOX,
    segment_start_hint=SEGMENT_START_HINT,
    segment_end_hint=SEGMENT_END_HINT,
    beats_per_minute_hint=BPM_HINT)
# Out:
# INFO:root:FETCHING_AUDIO
# INFO:root:Retrieving audio from https://foodgroup.bandcamp.com/track/universe
# INFO:root:DETECTING_BEATS
# INFO:root:EXTRACTING_FEATURES
# INFO:root:Feature extraction w/ Jukebox could take several minutes.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 14
#      11 from sheetsage.infer import sheetsage
#      13 logging.basicConfig(level=logging.INFO)
# ---> 14 lead_sheet, segment_beats, segment_beats_times = sheetsage(
#      15     AUDIO_URL,
#      16     use_jukebox=USE_JUKEBOX,
#      17     segment_start_hint=SEGMENT_START_HINT,
#      18     segment_end_hint=SEGMENT_END_HINT,
#      19     beats_per_minute_hint=BPM_HINT)
#
# File ~/chord_analysis/sheetsage/sheetsage/infer.py:680, in sheetsage(audio_path_bytes_or_url, segment_start_hint, segment_end_hint, use_jukebox, measures_per_chunk, segment_hints_are_downbeats, beats_per_measure_hint, beats_per_minute_hint, detect_melody, detect_harmony, melody_threshold, harmony_threshold, beat_detection_padding, avoid_chunking_if_possible, legacy_behavior, status_change_callback, return_intermediaries, tqdm)
#     678 if use_jukebox:
#     679     logging.info("Feature extraction w/ Jukebox could take several minutes.")
# --> 680 chunks_features = _extract_features(
#     681     audio_path_or_bytes, input_feats, tertiaries_times, chunks_tertiaries, tqdm
#     682 )
#     684 # Transcribe chunks
#     685 status_change_callback(Status.TRANSCRIBING)
#
# File ~/chord_analysis/sheetsage/sheetsage/infer.py:352, in _extract_features(audio_path_or_bytes, input_feats, tertiaries_times, chunks_tertiaries, tqdm)
#     349 if np.any(tertiary_diff_frames.astype(np.int64) == 0):
#     350     raise ValueError("Tempo too fast for beat-informed feature resampling")
# --> 352 extractor = _init_extractor(input_feats)
#     353 chunks_features = []
#     354 with tempfile.NamedTemporaryFile("wb") as f:
#
# File ~/chord_analysis/sheetsage/sheetsage/infer.py:87, in _init_extractor(input_feats)
#      85     extractor = Handcrafted()
#      86 elif input_feats == InputFeats.JUKEBOX:
# ---> 87     extractor = Jukebox()
#      88 else:
#      89     raise ValueError()
#
# File ~/chord_analysis/sheetsage/sheetsage/representations/__init__.py:17, in Jukebox.__init__(self)
#      16 def __init__(self):
# ---> 17     raise ImportError("Jukebox module not installed. Install it separately if needed.")
#
# ImportError: Jukebox module not installed. Install it separately if needed.

# %%
# Display lead sheet

from IPython.display import display, Image

from sheetsage.utils import engrave

lead_sheet_png = engrave(lead_sheet.as_lily())
display(Image(lead_sheet_png))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       3 from IPython.display import display, Image
#       5 from sheetsage.utils import engrave
# ----> 7 lead_sheet_png = engrave(lead_sheet.as_lily())
#       8 display(Image(lead_sheet_png))
#
# NameError: name 'lead_sheet' is not defined

# %%
# Create MIDI

from io import BytesIO
import pretty_midi

from sheetsage.align import create_beat_to_time_fn

beat_to_time_fn = create_beat_to_time_fn(segment_beats, segment_beats_times)
midi_bytes = lead_sheet.as_midi(beat_to_time_fn)
midi = pretty_midi.PrettyMIDI(BytesIO(midi_bytes))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 import pretty_midi
#       6 from sheetsage.align import create_beat_to_time_fn
# ----> 8 beat_to_time_fn = create_beat_to_time_fn(segment_beats, segment_beats_times)
#       9 midi_bytes = lead_sheet.as_midi(beat_to_time_fn)
#      10 midi = pretty_midi.PrettyMIDI(BytesIO(midi_bytes))
#
# NameError: name 'segment_beats' is not defined

# %%
# 
# Synthesize aligned transcription preview

import librosa
from IPython.display import display, Audio

from sheetsage.utils import retrieve_audio_bytes

start_time = beat_to_time_fn(0)
end_time = beat_to_time_fn(lead_sheet[-1] / 4)
audio, sr = librosa.load(
    BytesIO(retrieve_audio_bytes(AUDIO_URL)),
    offset=start_time,
    duration=end_time - start_time,
    mono=True)
preview = midi.fluidsynth(fs=sr)
preview = preview[round(start_time * sr):]
preview = preview[:audio.shape[0]]
display(Audio([audio, preview], rate=sr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5 from IPython.display import display, Audio
#       7 from sheetsage.utils import retrieve_audio_bytes
# ----> 9 start_time = beat_to_time_fn(0)
#      10 end_time = beat_to_time_fn(lead_sheet[-1] / 4)
#      11 audio, sr = librosa.load(
#      12     BytesIO(retrieve_audio_bytes(AUDIO_URL)),
#      13     offset=start_time,
#      14     duration=end_time - start_time,
#      15     mono=True)
#
# NameError: name 'beat_to_time_fn' is not defined
